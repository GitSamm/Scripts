# %%
# This script is only used to measure convergence of coating energies/thermal noise.

# %%
import math
import numpy as np
import matplotlib
from matplotlib import pyplot as plt
import matplotlib.patches as mpatches
from matplotlib.backends.backend_pdf import PdfPages
from matplotlib.ticker import FuncFormatter, MaxNLocator

#matplotlib.rcParams['text.usetex'] = True
#plt.style.use('dark_background')

# %%
data   = np.genfromtxt("Stan.dat")
data_1 = np.genfromtxt("refineByDIts6.dat")
data_2 = np.genfromtxt("GlobalRefinementDouble.dat")

# %%
bulkEnergy = data[:,10]
bulkEnergyDropLast = bulkEnergy[:-1]
bulkEnergyDropFirst = bulkEnergy[1:]
bulkEnergyDiff = np.abs(bulkEnergyDropLast - bulkEnergyDropFirst)
bulkEnergyDiffFrac = bulkEnergyDiff / bulkEnergyDropLast

shearEnergy = data[:,11]
shearEnergyDropLast = shearEnergy[:-1]
shearEnergyDropFirst = shearEnergy[1:]
shearEnergyDiff = np.abs(shearEnergyDropLast - shearEnergyDropFirst)
shearEnergyDiffFrac = shearEnergyDiff / shearEnergyDropLast

bulkEnergyOvershearEnergy = data[:,10]/data[:,11]
bulkEnergyOvershearEnergyDropLast = bulkEnergyOvershearEnergy[:-1]
bulkEnergyOvershearEnergyDropFirst = bulkEnergyOvershearEnergy[1:]
bulkEnergyOvershearEnergyDiff = np.abs(bulkEnergyOvershearEnergyDropLast - bulkEnergyOvershearEnergyDropFirst)
bulkEnergyOvershearEnergyDiffFrac = bulkEnergyOvershearEnergyDiff / bulkEnergyOvershearEnergyDropLast

totalEnergy = data[:,1]
totalEnergyDropLast = totalEnergy[:-1]
totalEnergyDropFirst = totalEnergy[1:]
totalEnergyDiff = np.abs(totalEnergyDropLast - totalEnergyDropFirst)
totalEnergyDiffFrac = totalEnergyDiff / totalEnergyDropLast

coatEnergy = data[:,3]
coatEnergyDropLast = coatEnergy[:-1]
coatEnergyDropFirst = coatEnergy[1:]
coatEnergyDiff = np.abs(coatEnergyDropLast - coatEnergyDropFirst)
coatEnergyDiffFrac = coatEnergyDiff / coatEnergyDropLast

coatingThermalNoise = data[:,5]
coatThermalNoiseDropLast  = coatingThermalNoise[:-1]
coatThermalNoiseDropFirst = coatingThermalNoise[1:]
coatThermalNoiseDiff = np.abs(coatThermalNoiseDropLast - coatThermalNoiseDropFirst)
coatThermalNoiseDiffFrac = coatThermalNoiseDiff / coatThermalNoiseDropLast

# %%
bulkEnergy_1 = data_1[:,10]
bulkEnergyDropLast_1 = bulkEnergy_1[:-1]
bulkEnergyDropFirst_1 = bulkEnergy_1[1:]
bulkEnergyDiff_1 = np.abs(bulkEnergyDropLast_1 - bulkEnergyDropFirst_1)
bulkEnergyDiffFrac_1 = bulkEnergyDiff_1 / bulkEnergyDropLast_1

shearEnergy_1 = data_1[:,11]
shearEnergyDropLast_1 = shearEnergy_1[:-1]
shearEnergyDropFirst_1 = shearEnergy_1[1:]
shearEnergyDiff_1 = np.abs(shearEnergyDropLast_1 - shearEnergyDropFirst_1)
shearEnergyDiffFrac_1 = shearEnergyDiff_1 / shearEnergyDropLast_1

bulkEnergyOvershearEnergy_1 = data_1[:,10]/data_1[:,11]
bulkEnergyOvershearEnergyDropLast_1 = bulkEnergyOvershearEnergy_1[:-1]
bulkEnergyOvershearEnergyDropFirst_1 = bulkEnergyOvershearEnergy_1[1:]
bulkEnergyOvershearEnergyDiff_1 = np.abs(bulkEnergyOvershearEnergyDropLast_1 - bulkEnergyOvershearEnergyDropFirst_1)
bulkEnergyOvershearEnergyDiffFrac_1 = bulkEnergyOvershearEnergyDiff_1 / bulkEnergyOvershearEnergyDropLast_1

totalEnergy_1 = data_1[:,1]
totalEnergyDropLast_1 = totalEnergy_1[:-1]
totalEnergyDropFirst_1 = totalEnergy_1[1:]
totalEnergyDiff_1 = np.abs(totalEnergyDropLast_1 - totalEnergyDropFirst_1)
totalEnergyDiffFrac_1 = totalEnergyDiff_1 / totalEnergyDropLast_1

coatEnergy_1 = data_1[:,3]
coatEnergyDropLast_1 = coatEnergy_1[:-1]
coatEnergyDropFirst_1 = coatEnergy_1[1:]
coatEnergyDiff_1 = np.abs(coatEnergyDropLast_1 - coatEnergyDropFirst_1)
coatEnergyDiffFrac_1 = coatEnergyDiff_1 / coatEnergyDropLast_1

coatingThermalNoise_1 = data_1[:,5]
coatThermalNoiseDropLast_1  = coatingThermalNoise_1[:-1]
coatThermalNoiseDropFirst_1 = coatingThermalNoise_1[1:]
coatThermalNoiseDiff_1 = np.abs(coatThermalNoiseDropLast_1 - coatThermalNoiseDropFirst_1)
coatThermalNoiseDiffFrac_1 = coatThermalNoiseDiff_1 / coatThermalNoiseDropLast_1

# %%
bulkEnergy_2 = data_2[:,10]
bulkEnergyDropLast_2 = bulkEnergy_2[:-1]
bulkEnergyDropFirst_2 = bulkEnergy_2[1:]
bulkEnergyDiff_2 = np.abs(bulkEnergyDropLast_2 - bulkEnergyDropFirst_2)
bulkEnergyDiffFrac_2 = bulkEnergyDiff_2 / bulkEnergyDropLast_2

shearEnergy_2 = data_2[:,11]
shearEnergyDropLast_2 = shearEnergy_2[:-1]
shearEnergyDropFirst_2 = shearEnergy_2[1:]
shearEnergyDiff_2 = np.abs(shearEnergyDropLast_2 - shearEnergyDropFirst_2)
shearEnergyDiffFrac_2 = shearEnergyDiff_2 / shearEnergyDropLast_2

bulkEnergyOvershearEnergy_2 = data_2[:,10]/data_2[:,11]
bulkEnergyOvershearEnergyDropLast_2 = bulkEnergyOvershearEnergy_2[:-1]
bulkEnergyOvershearEnergyDropFirst_2 = bulkEnergyOvershearEnergy_2[1:]
bulkEnergyOvershearEnergyDiff_2 = np.abs(bulkEnergyOvershearEnergyDropLast_2 - bulkEnergyOvershearEnergyDropFirst_2)
bulkEnergyOvershearEnergyDiffFrac_2 = bulkEnergyOvershearEnergyDiff_2 / bulkEnergyOvershearEnergyDropLast_2

totalEnergy_2 = data_2[:,1]
totalEnergyDropLast_2 = totalEnergy_2[:-1]
totalEnergyDropFirst_2 = totalEnergy_2[1:]
totalEnergyDiff_2 = np.abs(totalEnergyDropLast_2 - totalEnergyDropFirst_2)
totalEnergyDiffFrac_2 = totalEnergyDiff_2 / totalEnergyDropLast_2

coatEnergy_2 = data_2[:,3]
coatEnergyDropLast_2 = coatEnergy_2[:-1]
coatEnergyDropFirst_2 = coatEnergy_2[1:]
coatEnergyDiff_2 = np.abs(coatEnergyDropLast_2 - coatEnergyDropFirst_2)
coatEnergyDiffFrac_2 = coatEnergyDiff_2 / coatEnergyDropLast_2

coatingThermalNoise_2 = data_2[:,5]
coatThermalNoiseDropLast_2  = coatingThermalNoise_2[:-1]
coatThermalNoiseDropFirst_2 = coatingThermalNoise_2[1:]
coatThermalNoiseDiff_2 = np.abs(coatThermalNoiseDropLast_2 - coatThermalNoiseDropFirst_2)
coatThermalNoiseDiffFrac_2 = coatThermalNoiseDiff_2 / coatThermalNoiseDropLast_2

# %%
mySubfig, mySubax = plt.subplots(2, 2)
mySubfig.suptitle('Effective Isotropic AlGaAs', fontsize=25, color='w', y=1.04)
color1='cyan'
color2='orangered'
color3='white'

gridwidth_1=0.5
gridcolor_1=(0.8,0.8,0.8)

myAxisLabelSize_1=28
myTickLabelSize_1=18
myLegendSize=5

# Upper Left Plot
mySubax[0,0].plot(data[:,0][:-1], bulkEnergyDiffFrac, marker='x', label='QuadFormFive', color=color1)
mySubax[0,0].plot(data_1[:,0][:-1], bulkEnergyDiffFrac_1, marker='o', label='refineByDIts6', color=color2)
mySubax[0,0].plot(data_2[:,0][:-1], bulkEnergyDiffFrac_2, marker='p', label='GlobalRefinementDouble', color=color3)

mySubax[0,0].set_yscale('log')
mySubax[0,0].set_title('Bulk Energy')
mySubax[0,0].grid(b=True, which='major', color=gridcolor_1, linestyle='solid')
mySubax[0,0].tick_params(axis='x', pad=5, length=1)
mySubax[0,0].tick_params(which='minor', length=1)
mySubax[0,0].tick_params(axis='y', length=1)
mySubax[0,0].legend(loc='lower left', fontsize=myLegendSize)
mySubax[0,0].set_xlim([-1,12])

# Upper Right Plot

mySubax[0,1].plot(data[:,0][:-1], shearEnergyDiffFrac, marker='x', label='QuadFormFive', color=color1)
mySubax[0,1].plot(data_1[:,0][:-1], shearEnergyDiffFrac_1, marker='o', label='refineByDIts6', color=color2)
mySubax[0,1].plot(data_2[:,0][:-1], shearEnergyDiffFrac_2, marker='p', label='GlobalRefinementDouble', color=color3)

mySubax[0,1].set_yscale('log')
mySubax[0,1].set_title('Shear Energy')
mySubax[0,1].grid(b=True, which='major', color=gridcolor_1, linestyle='solid')
mySubax[0,1].tick_params(axis='x', pad=5, length=1)
mySubax[0,1].tick_params(which='minor', length=1)
mySubax[0,1].tick_params(axis='y', length=1)
mySubax[0,1].legend(loc='lower left', fontsize=myLegendSize)
mySubax[0,1].set_xlim([-1,12])

# Lower left plot
mySubax[1,0].plot(data[:,0][:-1], bulkEnergyOvershearEnergyDiffFrac, marker='x', label='QuadFormFive', color=color1)
mySubax[1,0].plot(data_1[:,0][:-1], bulkEnergyOvershearEnergyDiffFrac_1, marker='o', label='refineByDIts6', color=color2)
mySubax[1,0].plot(data_2[:,0][:-1], bulkEnergyOvershearEnergyDiffFrac_2, marker='p', label='GlobalRefinementDouble', color=color3)

mySubax[1,0].set_yscale('log')
mySubax[1,0].set_title('Bulk Energy Over Shear Energy')
mySubax[1,0].grid(b=True, which='major', color=gridcolor_1, linestyle='solid')
mySubax[1,0].tick_params(axis='x', pad=5, length=1)
mySubax[1,0].tick_params(which='minor', length=1)
mySubax[1,0].tick_params(axis='y', length=1)
mySubax[1,0].legend(loc='lower left', fontsize=myLegendSize)
mySubax[1,0].set_xlim([-1,12])


# Lower right plot
mySubax[1,1].plot(data[:,0][:-1], coatEnergyDiffFrac, marker='x', label='QuadFormFive', color=color1)
mySubax[1,1].plot(data_1[:,0][:-1], coatEnergyDiffFrac_1, marker='o', label='refineByDIts6', color=color2)
mySubax[1,1].plot(data_2[:,0][:-1], coatEnergyDiffFrac_2, marker='p', label='GlobalRefinementDouble', color=color3)

mySubax[1,1].set_yscale('log')
mySubax[1,1].set_title('Coating Energy')
mySubax[1,1].grid(b=True, which='major', color=gridcolor_1, linestyle='solid')
mySubax[1,1].tick_params(axis='x', pad=5, length=1)
mySubax[1,1].tick_params(which='minor', length=1)
mySubax[1,1].tick_params(axis='y', length=1)
mySubax[1,1].legend(loc='lower left', fontsize=myLegendSize)
mySubax[1,1].set_xlim([-1,12])

# Add the x and y axis labels
for ax in mySubax.flat:
    ax.set(xlabel='$N$', ylabel='$|E_{N+1} - E_{N}|/ E_{N+1}$')

#txt = r'$r_0 : {}$'.format(r_0_multiplier)
#mySubfig.text(.55, .5, txt, ha='center', fontweight='bold', fontsize=18)


mySubfig.tight_layout()
plt.tight_layout()
plt.savefig('SubPlots.png', dpi=300, bbox_inches = "tight")

pdf = PdfPages('SubPlots.pdf')
pdf.savefig(dpi=300, bbox_inches = "tight")
pdf.close()

# %%
r_0_multiplier = 1.0
r_0 = 152.3108006676e-6 * r_0_multiplier
kB = 1.3806488e-23
# Temperature used and defined in the code
T = 305.
# Frequency
f = 100.
# Some papers use this def of r0.
wm = r_0 * np.sqrt(2)

F0 =  0.001
d = 4.68e-6
R = 12500.e-6

# Loss angles of the coating.
# Recall for a substrate with a single coating
# phi_FusedSilica = 1.e-6
# phi_Iso_Ta2O5 = 4.e-4
# phi_iso_AlGaAs = 2.5e-5
# phi_AlGaAs = 2.5 e-5

phiSub = 1.e-6
phiCoat = 2.5e-5

phiBulk = 7.75e-4
phiShear = 5.2e-7

# Possion ratio and Youngs modulus for a fused silica substrate.
ymSub = 72.E9
sigmaSub = 0.17

# Possion ratio and Youngs modulus for a isotropic AlGaAs coating.
ymCoat = 100.E9
sigmaCoat = 0.32

# Bulk and shear modulus for the coating, taken from Thorne + Blanford eq. 11.39
# We refer to mu as the shear modulus and K as the bulk modulus.

mu_coating = ymCoat/(2*(1 + sigmaCoat))
K_coating  = ymCoat/(3*(1 - 2*sigmaCoat))

# Bulk and shear modulus for the substrate, , taken from Thorne + Blanford eq. 11.39
mu_substrate = ymSub / (2*(1 + sigmaSub))
K_substrate  = ymSub / (3*(1 - 2*sigmaSub))

# %%
coatingEnergy = data[:,3]
CoatEnergyNumerical = coatingEnergy[-1] * 1E-6 # To get to SI units

coatingNoise = data[:,5] 
CoatThermalNoiseNumerical = coatingNoise[-1] / np.sqrt(100) # np.sqrt(f)

bulkEnergy = data[:,10]
shearEnergy = data[:,11]

bulkEnergyNumerical = bulkEnergy[-1] * 1e-6 # To get to SI units
shearEnergyNumerical = shearEnergy[-1] * 1e-6 # To get to SI units

# %%
coatingEnergy_1 = data_1[:,3]
CoatEnergyNumerical_1 = coatingEnergy_1[-1] * 1E-6 # To get to SI units

coatingNoise_1 = data_1[:,5] 
CoatThermalNoiseNumerical_1 = coatingNoise_1[-1] / np.sqrt(100) # np.sqrt(f)

bulkEnergy_1 = data_1[:,10]
shearEnergy_1 = data_1[:,11]

bulkEnergyNumerical_1 = bulkEnergy_1[-1] * 1e-6 # To get to SI units
shearEnergyNumerical_1 = shearEnergy_1[-1] * 1e-6 # To get to SI units

# %%
# This was the origonal formula used in the paper
# DOI: 	10.1088/1361-6382/aa9ccc
analytic_defunct = np.sqrt((2*kB*T/((math.pi**2)*f))*((1-(sigmaSub**2))/(wm*ymSub))*(d/wm)*((phiCoat)/(ymSub*ymCoat*(1-sigmaCoat**2)*(1-sigmaSub**2)))*(ymCoat**2*(1+sigmaSub)**2*(1-2*sigmaSub)**2+ymSub**2*(1+sigmaCoat)**2*(1-2*sigmaCoat)))

# These equations are ones I derived. They are the analytic solutions to the bulk/shear energies.
# We define the coating energy in terms of the bulk/shear energies which are defined in terms of 

# Equation 17
K_theta = (K_substrate + (mu_substrate / 3) + mu_coating) / ( (K_coating + ((4 / 3) * mu_coating))*(K_substrate + (mu_substrate/3)) )
# Equation 18
K_zz = (K_substrate + (mu_substrate / 3) + (mu_coating / 3) - (K_coating / 2) ) / ( (K_coating + ((4 / 3) * mu_coating))*(K_substrate + (mu_substrate/3)) )

# The energies, multiplied by their respective loss angle
bulk_energy_analytic = (d * K_coating * pow(K_theta, 2)) / (4 * math.pi * r_0**2)
shear_energy_analytic = ((2 * d * mu_coating  * (pow((K_theta - K_zz), 2) + pow(K_zz, 2))) - ((2 * d * mu_coating * pow(K_theta, 2))/3)) / (4 * math.pi * r_0**2)

# Coating Energy
analytic_coating_energy = (bulk_energy_analytic + shear_energy_analytic)

# Coating Thermal Noise
analytic_coating_thermal_noise = np.sqrt(((4 * kB * T) / (math.pi * f)) * (bulk_energy_analytic * phiBulk + shear_energy_analytic * phiShear))


# As a test, we can check to see how well the equation from Geoffrey's paper and the equations I have been using agree.

print(analytic_defunct)
print(analytic_coating_thermal_noise)
# Out:
# 6.527843637825414e-19
# 3.1482333694915496e-18

# %%
# Lets measure the numerical results to the analytic results.

# Percent Difference, with a being the analytic solution
def PercentDifference(a, b):
    return(100 * np.abs(a-b)/a)

print("All of these calculations are for the thermal noise run with quarature = 20")

print("Analytic bulk energy is ", bulk_energy_analytic, ".")
print("Numerical bulk energy, q = 20, is ", bulkEnergyNumerical, ".")
print("Numerical bulk energy, q = 10, is ", bulkEnergyNumerical_1, ".")
print("Their percent difference is ", PercentDifference(bulk_energy_analytic, bulkEnergyNumerical), "%.\n")

print("Analytic shear energy is ", shear_energy_analytic, ".")
print("Numerical shear energy, q = 20, is ", shearEnergyNumerical, ".")
print("Numerical shear energy, q = 10, is ", shearEnergyNumerical_1, ".")
print("Their percent difference is ", PercentDifference(shear_energy_analytic, shearEnergyNumerical), "%.\n")
print("One reason that the shear energy might be so much higher is numerical accuracy. If you look at the equation for shear energy, we have a lot more terms.\n")

print("Analytic Coating Energy is ", analytic_coating_energy, ".")
print("Numerical Coating Energy, q = 20, is ", CoatEnergyNumerical, ".")
print("Numerical Coating Energy, q = 10, is ", CoatEnergyNumerical_1, ".")
print("Their percent difference is ", PercentDifference(analytic_coating_energy, CoatEnergyNumerical), "%.\n")

print("Analytic Coating Thermal Noise is ", analytic_coating_thermal_noise, ".")
print("Numerical Coating Thermal Noise, q = 20, is ", CoatThermalNoiseNumerical, ".")
print("Numerical Coating Thermal Noise, q = 10, is ", CoatThermalNoiseNumerical_1, ".")
print("Their percent difference is ", PercentDifference(analytic_coating_thermal_noise, CoatThermalNoiseNumerical), "%.")
# Out:
# All of these calculations are for the thermal noise run with quarature = 20
# Analytic bulk energy is  2.3847447442940713e-10 .
# Numerical bulk energy, q = 20, is  2.1776130198894e-10 .
# Numerical bulk energy, q = 10, is  2.1797824100281998e-10 .
# Their percent difference is  8.685697909609447 %.
#
# Analytic shear energy is  7.943707075301387e-11 .
# Numerical shear energy, q = 20, is  6.1926125807413e-11 .
# Numerical shear energy, q = 10, is  6.1859363327868e-11 .
# Their percent difference is  22.043794892747215 %.
#
# One reason that the shear energy might be so much higher is numerical accuracy. If you look at the equation for shear energy, we have a lot more terms.
#
# Analytic Coating Energy is  3.17911545182421e-10 .
# Numerical Coating Energy, q = 20, is  2.7968742779635e-10 .
# Numerical Coating Energy, q = 10, is  2.7983760433069e-10 .
# Their percent difference is  12.023507156412835 %.
#
# Analytic Coating Thermal Noise is  3.1482333694915496e-18 .
# ...
